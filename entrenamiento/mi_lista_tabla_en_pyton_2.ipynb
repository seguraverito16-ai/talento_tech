# %%
mi_lista=[1,2,3,4,8,"veronica",4.5]
print(mi_lista)

campista=["veronica","segura",20,4.5,"calle 4"]
print(campista[1])
print(campista[0:3])
print("la direccion del campista es:",campista[4])
print(campista[-1])

print(len(campista))
campista.append("comunicacion")
print(campista)
celular=int(input("cual es tu numero de celular:"))
campista.append(3128928228)
print(campista)
barrio=input("cual es tu barrio:")
campista.insert(5,barrio)
print(campista)
lista_final=mi_lista + campista
print(lista_final)
print("veronica"in campista)
print("segura"in campista)
print(campista.index(comunicacion"))
campista.pop(1)
print(campista)
campista.remove("calle 4")
print(campista)
mi_lista.clear()
print(mi_lista)
campista.reverse()
print(campista)
campistas=["hugo","paco","luis","mateo","ana"]
campista.sort()
print(campistas)
campista.sort(reverse=true)
print(campistas)
conjunto=set(campistas)
campistas=list(conjunto)
print(campistas)
# Out:
# [1, 2, 3, 4, 8, 'veronica', 4.5]
# segura
# ['veronica', 'segura', 20]
# la direccion del campista es: calle 4
# calle 4
# 5
# ['veronica', 'segura', 20, 4.5, 'calle 4', 'comunicacion']
# cual es tu numero de celular:3128928228
# ['veronica', 'segura', 20, 4.5, 'calle 4', 'comunicacion', 3128928228]
# cual es tu barrio:cajibio
# ['veronica', 'segura', 20, 4.5, 'calle 4', 'cajibio', 'comunicacion', 3128928228]
# [1, 2, 3, 4, 8, 'veronica', 4.5, 'veronica', 'segura', 20, 4.5, 'calle 4', 'cajibio', 'comunicacion', 3128928228]
